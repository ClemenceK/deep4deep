# get_dealroom_meta_description 0.45
# get_dealroom_meta_description 1.35
# get_dealroom_meta_description 1.23
# get_dealroom_meta_description 0.54
# get_dealroom_meta_description 0.44
# get_dealroom_meta_description 1.24
# get_dealroom_meta_description 1.22
# get_dealroom_meta_description 0.53
# get_dealroom_meta_description 0.44
# get_dealroom_meta_description 1.17
# get_dealroom_meta_description 1.2
# get_dealroom_meta_description 0.41
# get_dealroom_meta_description 1.0
# get_dealroom_meta_description 0.45
# get_dealroom_meta_description 1.16
# ...
# get_meta_description 0.19
# get_meta_description 0.76
# website http://www.wegoto.eu request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.07
# website https://dsinstruments.fr/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.14
# get_meta_description 0.85
# website http://vaiomer.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.2
# website http://www.altaroad.com/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.3
# get_meta_description 1.74
# get_meta_description 0.49
# website http://www.acute3d.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 1.27
# get_meta_description 0.9
# website https://www.cardio-renal.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.15
# get_meta_description 0.87
# get_meta_description 1.88
# website http://vocal-apps.com/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 3.57
# website http://catopsys.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 1.18
# website http://atlangram.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.66
# website http://agv-discovery.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.17
# website http://myakiatto.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.7
# website http://pollen-robotics.com/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.41
# website http://www.anaquant.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.61
# website http://deltalys.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.22
# website http://www.diva-cloud.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 75.13
# get_meta_description 0.57
# get_meta_description 3.61
# get_meta_description 4.61
# get_meta_description 0.64
# website http://emersya.com/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.4
# website https://enovasense.com/en#top request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.18
# website http://e-ophtalmo.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 2.76
# website http://e-sims.fr/en/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 1.48
# get_meta_description 2.34
# get_meta_description 0.38
# website nan request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.0
# get_meta_description 1.35
# website http://www.fastlite.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.23
# get_meta_description 5.02
# get_meta_description 0.78
# website http://www.gema-life.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 2.83
# WARNING:urllib3.connection:Certificate did not match expected hostname: holdies.com. Certificate: {'subject': ((('commonName', 'trimet.asystom.com'),),), 'issuer': ((('countryName', 'US'),), (('organizationName', "Let's Encrypt"),), (('commonName', "Let's Encrypt Authority X3"),)), 'version': 3, 'serialNumber': '04058876C85C3506073F5D3510D0EFD13390', 'notBefore': 'Nov 10 11:30:42 2020 GMT', 'notAfter': 'Feb  8 11:30:42 2021 GMT', 'subjectAltName': (('DNS', 'trimet.asystom.com'), ('DNS', 'www.trimet.asystom.com')), 'OCSP': ('http://ocsp.int-x3.letsencrypt.org',), 'caIssuers': ('http://cert.int-x3.letsencrypt.org/',)}
# get_meta_description 7.7
# website https://holdies.com/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.14
# get_meta_description 0.97
# get_meta_description 0.3
# website http://jobtruster.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 75.14
# get_meta_description 0.29
# get_meta_description 2.29
# get_meta_description 0.77
# get_meta_description 1.52
# get_meta_description 3.69
# website http://lixoft.eu request threw an error, imputing dealroom_meta_description instead
# get_meta_description 1.21
# get_meta_description 3.35
# website http://makitoo.com/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.17
# website http://www.malkyrs.com/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 75.92
# get_meta_description 1.65
# get_meta_description 2.18
# website http://metadesk.io request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.48
# website http://metrixware.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 1.66
# get_meta_description 0.14
# WARNING:urllib3.connection:Certificate did not match expected hostname: moovlab.fr. Certificate: {'subject': ((('commonName', 'www.moovlab.fr'),),), 'issuer': ((('countryName', 'US'),), (('organizationName', "Let's Encrypt"),), (('commonName', "Let's Encrypt Authority X3"),)), 'version': 3, 'serialNumber': '049DE319CF220EC00D80A80AAB399110805C', 'notBefore': 'Oct 29 13:10:41 2020 GMT', 'notAfter': 'Jan 27 13:10:41 2021 GMT', 'subjectAltName': (('DNS', 'www.moovlab.fr'),), 'OCSP': ('http://ocsp.int-x3.letsencrypt.org',), 'caIssuers': ('http://cert.int-x3.letsencrypt.org/',)}
# website https://moon.xyz request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.32
# website http://moovlab.fr request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.14
# website http://payname.fr request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.07
# get_meta_description 1.18
# website http://www.museopic.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 2.78
# get_meta_description 0.63
# website http://myrissi.fr request threw an error, imputing dealroom_meta_description instead
# get_meta_description 1.62
# website http://naturalpad.fr request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.32
# website https://neop.eu request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.26
# website http://www.neosensys.com/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.93
# get_meta_description 2.03
# get_meta_description 3.37
# get_meta_description 0.42
# website http://apidaze.io request threw an error, imputing dealroom_meta_description instead
# get_meta_description 2.64
# website http://ozcar.io request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.61
# get_meta_description 1.89
# get_meta_description 1.71
# website https://www.piwio.fr/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 1.32
# get_meta_description 3.64
# website http://quantia-inc.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.08
# website http://quickdo.fr request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.11
# get_meta_description 1.2
# get_meta_description 1.19
# WARNING:urllib3.connection:Certificate did not match expected hostname: gong-aphasie.fr. Certificate: {'subject': ((('countryName', 'US'),), (('stateOrProvinceName', 'Massachusetts'),), (('localityName', 'Cambridge'),), (('organizationName', 'Akamai Technologies, Inc.'),), (('commonName', 'a248.e.akamai.net'),)), 'issuer': ((('countryName', 'US'),), (('organizationName', 'DigiCert Inc'),), (('organizationalUnitName', 'www.digicert.com'),), (('commonName', 'DigiCert Secure Site ECC CA-1'),)), 'version': 3, 'serialNumber': '05A3A30BC52C268BCB22ADC7B47D6E28', 'notBefore': 'Jul 15 00:00:00 2020 GMT', 'notAfter': 'Sep 13 12:00:00 2021 GMT', 'subjectAltName': (('DNS', 'a248.e.akamai.net'), ('DNS', '*.akamaized.net'), ('DNS', '*.akamaihd-staging.net'), ('DNS', '*.akamaihd.net'), ('DNS', '*.akamaized-staging.net')), 'OCSP': ('http://ocsp.digicert.com',), 'caIssuers': ('http://cacerts.digicert.com/DigiCertSecureSiteECCCA-1.crt',), 'crlDistributionPoints': ('http://crl3.digicert.com/DigiCertSecureSiteECCCA-1.crl', 'http://crl4.digicert.com/DigiCertSecureSiteECCCA-1.crl')}
# get_meta_description 4.54
# website https://gong-aphasie.fr/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.2
# get_meta_description 1.35
# get_meta_description 3.04
# website http://www.alg-and-you.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.09
# get_meta_description 0.34
# website http://scool.fi/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.73
# website http://scorelab.io request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.26
# website http://semiotime.fr request threw an error, imputing dealroom_meta_description instead
# get_meta_description 3.48
# get_meta_description 1.16
# website http://shortouch.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.09
# website http://signactif.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.12
# website https://www.labri.fr/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 1.12
# website https://www.situ8ed.com/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.54
# website http://skwazel.fr request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.89
# get_meta_description 0.64
# website http://www.solgelway.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.31
# website http://springeo.fr/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.09
# get_meta_description 1.21
# WARNING:urllib3.connection:Certificate did not match expected hostname: sylha.io. Certificate: {'subject': ((('commonName', 'cluster021.hosting.ovh.net'),),), 'issuer': ((('countryName', 'GB'),), (('stateOrProvinceName', 'Greater Manchester'),), (('localityName', 'Salford'),), (('organizationName', 'Sectigo Limited'),), (('commonName', 'Sectigo RSA Domain Validation Secure Server CA'),)), 'version': 3, 'serialNumber': '8F0583FDA3A80DFF808FF69B04C3E740', 'notBefore': 'Jun  1 00:00:00 2020 GMT', 'notAfter': 'Jun  1 23:59:59 2021 GMT', 'subjectAltName': (('DNS', 'cluster021.hosting.ovh.net'), ('DNS', 'www.cluster021.hosting.ovh.net')), 'OCSP': ('http://ocsp.sectigo.com',), 'caIssuers': ('http://crt.sectigo.com/SectigoRSADomainValidationSecureServerCA.crt',)}
# get_meta_description 0.48
# website https://sylha.io/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.14
# website http://www.synectique.eu/en/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.25
# get_meta_description 2.25
# get_meta_description 2.35
# website http://www.terroiko.fr/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.17
# website http://tidalys.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.05
# website http://www.toutiterre.fr request threw an error, imputing dealroom_meta_description instead
# get_meta_description 2.62
# website https://www.traxxs.net/fr/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.75
# website http://tumbup.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 2.14
# get_meta_description 0.72
# get_meta_description 1.7
# get_meta_description 76.35
# website https://www.vesta-system.fr/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 1.9
# website http://www.wecover.fr/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 2.37
# website http://wever.fr request threw an error, imputing dealroom_meta_description instead
# get_meta_description 2.59
# website http://whoomies.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.68
# website http://widesens.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.19
# get_meta_description 0.17
# get_meta_description 1.84
# get_meta_description 3.72
# get_meta_description 1.38
# website http://www.4d-virtualiz.com/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.4
# get_meta_description 0.3
# get_meta_description 1.38
# get_meta_description 0.92
# website http://lequattrocento.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.2
# website http://www.ambientic.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.32
# website http://antofenol.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.15
# website https://antsway.com/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 1.03
# website http://www.appie-cidre.com/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.1
# WARNING:urllib3.connection:Certificate did not match expected hostname: aqsitania.com. Certificate: {'subject': ((('commonName', 'www.aqsitania.com'),),), 'issuer': ((('countryName', 'US'),), (('organizationName', "Let's Encrypt"),), (('commonName', "Let's Encrypt Authority X3"),)), 'version': 3, 'serialNumber': '039263EEC688DE23CCF306860682065D1716', 'notBefore': 'Oct 15 04:30:46 2020 GMT', 'notAfter': 'Jan 13 04:30:46 2021 GMT', 'subjectAltName': (('DNS', 'www.aqsitania.com'),), 'OCSP': ('http://ocsp.int-x3.letsencrypt.org',), 'caIssuers': ('http://cert.int-x3.letsencrypt.org/',)}
# website http://aqsitania.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.59
# website http://arthurdupuy.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.25
# get_meta_description 0.21
# get_meta_description 0.25
# get_meta_description 0.44
# get_meta_description 0.33
# get_meta_description 0.8
# get_meta_description 0.9
# website http://fr.beampulse.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.11
# website http://biin.mx request threw an error, imputing dealroom_meta_description instead
# get_meta_description 1.87
# website http://www.nirea-recycling.net/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.28
# get_meta_description 2.17
# get_meta_description 5.31
# website http://www.bker.io request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.19
# website http://www.calnesis.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 1.9
# get_meta_description 0.2
# get_meta_description 0.4
# get_meta_description 0.27
# website https://www.wearestim.com/fr/ request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.21
# website http://francelabs.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.22
# get_meta_description 0.71
# get_meta_description 4.0
# website http://ladevanture.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.43
# get_meta_description 0.69
# get_meta_description 1.92
# website http://opta-lp.com request threw an error, imputing dealroom_meta_description instead
# get_meta_description 0.6
# get_meta_description 0.23
# get_meta_description 1.89
# website http://powerup.xyz request threw an error, imputing dealroom_meta_description instead
# get_meta_description 1.55
# get_meta_description 0.96

# %% [markdown]
# ---
# # Retraining with all the data available

# %% [markdown]
# ---
# # Predicting

# %% [markdown]
# #### This code is what runs on the docker API

# %%
preprocessor = Preprocessor()

# %%
embedder = Embedder()
# Out:
# initializing Embedder
# downloading class transfer learning embedder – this may take time, coffee break maybe?

# %%
predictor = Predictor(preprocessor, embedder, "../deeptech_NLP_model")
# Out:
# initializing Preprocessor
# initializing Predictor

# %%
snippet_1 = "hi my name is tech biotech super tech I hire engineers and geniuses to research technically how nantechnologies contribute to deep learning processors performance using patented approaches"
snippet_2 = "I sell second hand stuff that would have been wasted otherwise, in an old school way, door to door…"
snippet_3 = "There are more and more humans. More and more of them need surgery. Orthopedics especially is driven primarily by age and weight so... yeah. It's going to be impossible to train as many surgeons, let alone good and experienced ones, as the world needs. So what do we do? Let people die of a fractured hip? We believe technology holds part of the answer. We believe the success or failure of a surgical intervention shouldn't be a direct result of the surgeon's state of mind. We believe it's possible to create tools that will improve both patient outcome and surgeon experience. We believe it's unacceptable to live in a world where *5 billion* people have no access to surgery whatsoever. We develop advanced robotics technologies for orthopedic surgeons. So that more people have access to life-changing orthopedic surgeries, safely and affordably. Freedom starts with movement. And we believe in what we do. Supported by A-Level entrepreneurs and innovators such as Bruno Maisonnier (Founder of Aldebaran Robotics, Founder & CEO AnotherBrain) and world-class orthopedic surgeons, we work hard to change the status quo in surgery.\ We are incubated at one of Europe's best life science incubator, Paris Biotech Santé (ever heard of DNAScript, Therapenacea and Therapixel ? They are here too). We have raised significant seed money. We have gathered a world-class team. We're all in. We're still hiring."
snippet_4 = "Created in June 2018, Ganymed Robotics ambitions to revolutionize the standard of care in Orthopedic surgery. Ganymed develops a revolutionary active therapeutic device to assist surgeons during knee replacement surgery. Working in close collaboration with high-volume orthopedic surgeons, researchers, entrepreneurs in Computer-Assisted Surgery and Robotics, the company has filed several patents and has been awarded numerous international and national prices, such as the I-LAB contest. With a truly innovative user-centered design and novel AI-based algorithms to perceive and extract knowledge from the surgical scene in a non-invasive manner, Ganymed improves patient outcome and surgeon experience."

# %%
dict_to_predict = {'id_1':snippet_1, 'id_2':snippet_2, 'Ganymed Robotics Linked_in':snippet_3, 'Ganymed Robotics Welcome Jungle':snippet_4}

# %%
dict_to_predict
# Out:
# {'id_1': 'hi my name is tech biotech super tech I hire engineers and geniuses to research technically how nantechnologies contribute to deep learning processors performance using patented approaches',
#  'id_2': 'I sell second hand stuff that would have been wasted otherwise, in an old school way, door to door…',
#  'Ganymed Robotics Linked_in': "There are more and more humans. More and more of them need surgery. Orthopedics especially is driven primarily by age and weight so... yeah. It's going to be impossible to train as many surgeons, let alone good and experienced ones, as the world needs. So what do we do? Let people die of a fractured hip? We believe technology holds part of the answer. We believe the success or failure of a surgical intervention shouldn't be a direct result of the surgeon's state of mind. We believe it's possible to create tools that will improve both patient outcome and surgeon experience. We believe it's unacceptable to live in a world where *5 billion* people have no access to surgery whatsoever. We develop advanced robotics technologies for orthopedic surgeons. So that more people have access to life-changing orthopedic surgeries, safely and affordably. Freedom starts with movement. And we believe in what we do. Supported by A-Level entrepreneurs and innovators such as Bruno Maisonnier (Founder of Aldebaran Robotics, Founder & CEO AnotherBrain) and world-class orthopedic surgeons, we work hard to change the status quo in surgery.\\ We are incubated at one of Europe's best life science incubator, Paris Biotech Santé (ever heard of DNAScript, Therapenacea and Therapixel ? They are here too). We have raised significant seed money. We have gathered a world-class team. We're all in. We're still hiring.",
#  'Ganymed Robotics Welcome Jungle': 'Created in June 2018, Ganymed Robotics ambitions to revolutionize the standard of care in Orthopedic surgery. Ganymed develops a revolutionary active therapeutic device to assist surgeons during knee replacement surgery. Working in close collaboration with high-volume orthopedic surgeons, researchers, entrepreneurs in Computer-Assisted Surgery and Robotics, the company has filed several patents and has been awarded numerous international and national prices, such as the I-LAB contest. With a truly innovative user-centered design and novel AI-based algorithms to perceive and extract knowledge from the surgical scene in a non-invasive manner, Ganymed improves patient outcome and surgeon experience.'}

# %% [markdown]
# ---
# # NLP: Fast API stored on docker querying

# %%
import requests
url = "https://text-deeptech-2w2uaoep4a-ew.a.run.app/pred"
params = {"company_descriptions": 
          {"Alice&Bob": "We build Universal, Error-free, Quantum Computers to help industries and researchers solve the hardest problems",
           "Flying Whales": "Developing the 'Large Capacity Airship 60 tons' for low-cost, point-to-point transport of heavy or bulky loads",
           "Doctolib": "An appointment online to a doctor or dentist",
           "Le_Wagon": "A coding bootcamp that teaches students to develop web applications from scratch."}}
response = requests.post(url, json=params)
response.json()
# Out:
# {'Alice&Bob': 0.7481144666671753,
#  'Flying Whales': 0.5127061009407043,
#  'Doctolib': 0.07383999973535538,
#  'Le_Wagon': 0.4659561812877655}

# %% [markdown]
# ---

# %% [markdown]
# ---
# # Preparing data for scoring

# %%
my_path = "../raw_data/data_cross_val/"
results_1 = pd.read_csv(my_path+"results_1.csv")
results_2 = pd.read_csv(my_path+"results_2.csv")
results_3 = pd.read_csv(my_path+"results_3.csv")

# %%
cath_path = "../raw_data/data_cross_val/y_pred_(RandomForest)/"
y_pred_forest_1 = pd.read_csv(cath_path+"y_pred1.csv")
y_pred_forest_2 = pd.read_csv(cath_path+"y_pred2.csv")
y_pred_forest_3 = pd.read_csv(cath_path+"y_pred3.csv")

# %%
#results_1['y_pred_forest'] = y_pred_forest_1['1']
results_1.shape
# Out:
# (441, 3)

# %%
y_pred_forest_1.shape
# Out:
# (329, 3)

# %%
results_1
# Out:
#           id            name  y_pred_NLP
# 0    1480999  OneFit Medical    0.480810
# 1    1891278           Olvid    0.189215
# 2     915273      Smart Cast    0.318964
# 3     210185           Swift    0.110053
# 4    1617246          Inalve    0.410868
# ..       ...             ...         ...
# 436   958928           Moona    0.157952
# 437  1309397        Redberry    0.243415
# 438  1618472          SeqOne    1.085975
# 439  1743249         DATEXIM    0.954664
# 440   898779        Diamlite    0.674003
#
# [441 rows x 3 columns]

# %% [markdown]
# ---
# # Computing my scores

# %%
from deep4deep.utils_w2v_rnn import make_X_check2, my_metrics

# %%
NLP_d1 = my_metrics(make_X_check2(results_1, name_for_y_pred='y_pred_NLP'))
NLP_d2 = my_metrics(make_X_check2(results_2, name_for_y_pred='y_pred_NLP'))
NLP_d3 = my_metrics(make_X_check2(results_3, name_for_y_pred='y_pred_NLP'))
# Out:
# accuracy: 79.14 %
# precision: 83.15 %
# recall: 71.50 %
# f1: 76.88 %
# Confusion matrix
# 79.0	83.0	71.0	77.0
# accuracy: 77.10 %
# precision: 80.87 %
# recall: 69.16 %
# f1: 74.56 %
# Confusion matrix
# 77.0	81.0	69.0	75.0
# accuracy: 76.87 %
# precision: 79.47 %
# recall: 70.56 %
# f1: 74.75 %
# Confusion matrix
# 77.0	79.0	71.0	75.0

# %%
# Precision
sum([NLP_d1['precision'],NLP_d2['precision'],NLP_d3['precision']])/3
# Out:
# 0.811667250211535

# %%
# Recall
sum([NLP_d1['recall'],NLP_d2['recall'],NLP_d3['recall']])/3
# Out:
# 0.7040498442367601

# %% [markdown]
# ---
# # Computing general scores

# %%
results_1.to_csv(my_path+"results_1.csv", index=False)
results_2.to_csv(my_path+"results_2.csv", index=False)
results_3.to_csv(my_path+"results_3.csv", index=False)

# %%
results_1.head()
# Out:
#              name                                          full_text  target  \
# 0  OneFit Medical  publisher of knee and hip surgery planning sof...     0.0
# 1           Olvid  Multiplatform encrypted instant messaging soft...     1.0
# 2      Smart Cast  Solutions in the field of construction  est un...     0.0
# 3           Swift  Student group at cal poly pomona dedicated to ...     0.0
# 4          Inalve  Develops sustainable algaculture for the produ...     1.0
#
#    y_pred_NLP
# 0    0.658518
# 1    0.442070
# 2    0.183853
# 3    0.321218
# 4    0.763757

# %%
y_pred_(RandomForest)

# %%
import numpy as np
l = [np.nan,4]
min(l), max(l), sum(l)
# Out:
# (nan, nan, nan)

# %%
#change target by Cath's pred
def take_measure(row, function):
    if row['y_pred_NLP'] == np.nan: 
        return row['target']
    if function == 'mean':
        return row[['target','y_pred_NLP']].mean()
    if function == 'min':
        return row[['target','y_pred_NLP']].min()
    if function == 'mean':
        return row[['target','y_pred_NLP']].max()
    else:
        print("not a known function")
        return None
    
take_measure(results_1.loc[159], 'mean')
# Out:
# 1.0

# %%
results_1[results_1.y_pred_NLP.isna()]
# Out:
#              name full_text  target  y_pred_NLP
# 11   Synovo Group       NaN     0.0         NaN
# 52    Spicetronic       NaN     0.0         NaN
# 63         ViJump       NaN     0.0         NaN
# 88     Black-line       NaN     0.0         NaN
# 128           Bcm       NaN     0.0         NaN
# 159        Yealth       NaN     1.0         NaN
# 327          Eyye       NaN     0.0         NaN
# 328     Ultimetas       NaN     1.0         NaN
# 332        Exolis       NaN     0.0         NaN
# 369     Datarocks       NaN     0.0         NaN
# 393     DRONE ACT       NaN     0.0         NaN

# %%
# recup scores de Catherine
# deal with (my) nans in différent ways
# essayer moyenne, min, max, faire colonnes
# appliquer seuils
# compute TP etc -> 4 scores pour chaque

# %% [markdown]
# ---
